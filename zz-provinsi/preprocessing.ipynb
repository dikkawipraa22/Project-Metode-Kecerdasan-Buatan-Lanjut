# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import joblib
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data

# %%
data = pd.read_csv('dataset/dataset.csv')
data
# Out:
#      provinsi      kabupaten  tahun  indeks_pembangunan_manusia  \
# 0        ACEH       Simeulue   2023                       68.06
# 1        ACEH   Aceh Singkil   2023                       70.14
# 2        ACEH   Aceh Selatan   2023                       68.44
# 3        ACEH  Aceh Tenggara   2023                       71.05
# 4        ACEH     Aceh Timur   2023                       69.32
# ...       ...            ...    ...                         ...
# 7191    PAPUA         Puncak   2010                       33.44
# 7192    PAPUA        Dogiyai   2010                       47.48
# 7193    PAPUA     Intan Jaya   2010                         NaN
# 7194    PAPUA         Deiyai   2010                         NaN
# 7195    PAPUA  Kota Jayapura   2010                       76.69
#
#       angka_harapan_hidup  rerata_lama_sekolah  harapan_lama_sekolah  \
# 0                  65.655                9.760                 14.28
# 1                  67.830                8.655                 14.35
# 2                  64.860                8.840                 14.70
# 3                  68.700               10.100                 14.27
# 4                  69.120                8.490                 13.07
# ...                   ...                  ...                   ...
# 7191               64.915                0.710                  2.84
# 7192               64.160                3.360                  7.85
# 7193                  NaN                  NaN                  4.12
# 7194                  NaN                  NaN                  9.06
# 7195               69.835               10.655                 13.64
#
#       pengeluaran_per_kapita
# 0                     7686.0
# 1                     9374.0
# 2                     8712.0
# 3                     8566.0
# 4                     9436.0
# ...                      ...
# 7191                  4752.0
# 7192                  4769.0
# 7193                     NaN
# 7194                     NaN
# 7195                 13903.0
#
# [7196 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7196 entries, 0 to 7195
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   provinsi                    7196 non-null   object
#  1   kabupaten                   7196 non-null   object
#  2   tahun                       7196 non-null   int64
#  3   indeks_pembangunan_manusia  7129 non-null   float64
#  4   angka_harapan_hidup         6614 non-null   float64
#  5   rerata_lama_sekolah         6614 non-null   float64
#  6   harapan_lama_sekolah        6799 non-null   float64
#  7   pengeluaran_per_kapita      7129 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 449.9+ KB

# %%
data.describe(include=object)
# Out:
#           provinsi      kabupaten
# count         7196           7196
# unique          34            514
# top     JAWA TIMUR  Kota Jayapura
# freq           532             14

# %%
data.describe()
# Out:
#              tahun  indeks_pembangunan_manusia  angka_harapan_hidup  \
# count  7196.000000                 7129.000000          6614.000000
# mean   2016.500000                   67.859839            68.996626
# std       4.031409                    7.070305             3.665020
# min    2010.000000                   19.620000            52.600000
# 25%    2013.000000                   64.180000            66.766250
# 50%    2016.500000                   67.790000            69.285000
# 75%    2020.000000                   71.720000            71.453750
# max    2023.000000                   88.280000            78.010000
#
#        rerata_lama_sekolah  harapan_lama_sekolah  pengeluaran_per_kapita
# count          6614.000000           6799.000000             7129.000000
# mean              7.981120             12.485158             9789.504278
# std               1.722349              1.509673             2688.739256
# min               0.250000              1.220000             3214.000000
# 25%               6.986250             11.790000             7963.000000
# 50%               7.875000             12.530000             9586.000000
# 75%               8.985000             13.275000            11242.000000
# max              13.005000             17.930000            24975.000000

# %% [markdown]
# ### Preprocessinng Data

# %% [markdown]
# ##### Cek Missing Value

# %%
data.isna().sum()
# Out:
# provinsi                        0
# kabupaten                       0
# tahun                           0
# indeks_pembangunan_manusia     67
# angka_harapan_hidup           582
# rerata_lama_sekolah           582
# harapan_lama_sekolah          397
# pengeluaran_per_kapita         67
# dtype: int64

# %% [markdown]
# ##### Hapus Missing Value

# %%
data = data.dropna()
data
# Out:
#      provinsi         kabupaten  tahun  indeks_pembangunan_manusia  \
# 0        ACEH          Simeulue   2023                       68.06
# 1        ACEH      Aceh Singkil   2023                       70.14
# 2        ACEH      Aceh Selatan   2023                       68.44
# 3        ACEH     Aceh Tenggara   2023                       71.05
# 4        ACEH        Aceh Timur   2023                       69.32
# ...       ...               ...    ...                         ...
# 7189    PAPUA  Mamberamo Tengah   2010                       39.37
# 7190    PAPUA            Yalimo   2010                       38.47
# 7191    PAPUA            Puncak   2010                       33.44
# 7192    PAPUA           Dogiyai   2010                       47.48
# 7195    PAPUA     Kota Jayapura   2010                       76.69
#
#       angka_harapan_hidup  rerata_lama_sekolah  harapan_lama_sekolah  \
# 0                  65.655                9.760                 14.28
# 1                  67.830                8.655                 14.35
# 2                  64.860                8.840                 14.70
# 3                  68.700               10.100                 14.27
# 4                  69.120                8.490                 13.07
# ...                   ...                  ...                   ...
# 7189               62.175                2.050                  5.76
# 7190               64.590                1.365                  5.22
# 7191               64.915                0.710                  2.84
# 7192               64.160                3.360                  7.85
# 7195               69.835               10.655                 13.64
#
#       pengeluaran_per_kapita
# 0                     7686.0
# 1                     9374.0
# 2                     8712.0
# 3                     8566.0
# 4                     9436.0
# ...                      ...
# 7189                  3844.0
# 7190                  4016.0
# 7191                  4752.0
# 7192                  4769.0
# 7195                 13903.0
#
# [6274 rows x 8 columns]

# %% [markdown]
# ##### Cek Duplikasi

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Encode 'provinsi' dan 'kabupaten'

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['provinsi'] = label_encoder.fit_transform(data['provinsi'])
data['kabupaten'] = label_encoder.fit_transform(data['kabupaten'])
data
# Out:
#       provinsi  kabupaten  tahun  indeks_pembangunan_manusia  \
# 0            0        447   2023                       68.06
# 1            0          5   2023                       70.14
# 2            0          4   2023                       68.44
# 3            0          8   2023                       71.05
# 4            0          9   2023                       69.32
# ...        ...        ...    ...                         ...
# 7189        23        322   2010                       39.37
# 7190        23        513   2010                       38.47
# 7191        23        413   2010                       33.44
# 7192        23         94   2010                       47.48
# 7195        23        204   2010                       76.69
#
#       angka_harapan_hidup  rerata_lama_sekolah  harapan_lama_sekolah  \
# 0                  65.655                9.760                 14.28
# 1                  67.830                8.655                 14.35
# 2                  64.860                8.840                 14.70
# 3                  68.700               10.100                 14.27
# 4                  69.120                8.490                 13.07
# ...                   ...                  ...                   ...
# 7189               62.175                2.050                  5.76
# 7190               64.590                1.365                  5.22
# 7191               64.915                0.710                  2.84
# 7192               64.160                3.360                  7.85
# 7195               69.835               10.655                 13.64
#
#       pengeluaran_per_kapita
# 0                     7686.0
# 1                     9374.0
# 2                     8712.0
# 3                     8566.0
# 4                     9436.0
# ...                      ...
# 7189                  3844.0
# 7190                  4016.0
# 7191                  4752.0
# 7192                  4769.0
# 7195                 13903.0
#
# [6274 rows x 8 columns]

# %% [markdown]
# ##### Visualisasi Data

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))
sns.regplot(x='provinsi', y='indeks_pembangunan_manusia', data=data, ax=axes[0,0], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='kabupaten', y='indeks_pembangunan_manusia', data=data, ax=axes[0,1], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='tahun', y='indeks_pembangunan_manusia', data=data, ax=axes[0,2], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='angka_harapan_hidup', y='indeks_pembangunan_manusia', data=data, ax=axes[0,3], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='rerata_lama_sekolah', y='indeks_pembangunan_manusia', data=data, ax=axes[1,0], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='harapan_lama_sekolah', y='indeks_pembangunan_manusia', data=data, ax=axes[1,1], line_kws={'color': 'red', 'linewidth': 2})
sns.regplot(x='pengeluaran_per_kapita', y='indeks_pembangunan_manusia', data=data, ax=axes[1,2], line_kws={'color': 'red', 'linewidth': 2})
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))
sns.histplot(data["provinsi"], kde=True, ax=axes[0, 0])
sns.histplot(data["kabupaten"], kde=True, ax=axes[0, 1])
sns.histplot(data["tahun"], kde=True, ax=axes[0, 2])
sns.histplot(data["angka_harapan_hidup"], kde=True, ax=axes[0, 3])
sns.histplot(data["rerata_lama_sekolah"], kde=True, ax=axes[1, 0])
sns.histplot(data["harapan_lama_sekolah"], kde=True, ax=axes[1, 1])
sns.histplot(data["pengeluaran_per_kapita"], kde=True, ax=axes[1, 2])
sns.histplot(data["indeks_pembangunan_manusia"], kde=True, ax=axes[1, 3])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Cek Korelasi Fitur

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1, linewidths=0.5, cbar_kws={'shrink': 0.8})
plt.title('Heatmap Korelasi Antar Variabel')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Seleksi Fitur

# %%
data = data.drop(columns= ['kabupaten', 'tahun'])
data
# Out:
#       provinsi  indeks_pembangunan_manusia  angka_harapan_hidup  \
# 0            0                       68.06               65.655
# 1            0                       70.14               67.830
# 2            0                       68.44               64.860
# 3            0                       71.05               68.700
# 4            0                       69.32               69.120
# ...        ...                         ...                  ...
# 7189        23                       39.37               62.175
# 7190        23                       38.47               64.590
# 7191        23                       33.44               64.915
# 7192        23                       47.48               64.160
# 7195        23                       76.69               69.835
#
#       rerata_lama_sekolah  harapan_lama_sekolah  pengeluaran_per_kapita
# 0                   9.760                 14.28                  7686.0
# 1                   8.655                 14.35                  9374.0
# 2                   8.840                 14.70                  8712.0
# 3                  10.100                 14.27                  8566.0
# 4                   8.490                 13.07                  9436.0
# ...                   ...                   ...                     ...
# 7189                2.050                  5.76                  3844.0
# 7190                1.365                  5.22                  4016.0
# 7191                0.710                  2.84                  4752.0
# 7192                3.360                  7.85                  4769.0
# 7195               10.655                 13.64                 13903.0
#
# [6274 rows x 6 columns]

# %% [markdown]
# ##### Cek Outlier

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 8))
data.boxplot(column=["provinsi"], ax=axes[0, 0])
data.boxplot(column=["indeks_pembangunan_manusia"], ax=axes[0, 1])
data.boxplot(column=["harapan_lama_sekolah"], ax=axes[0, 2])
data.boxplot(column=["pengeluaran_per_kapita"], ax=axes[1, 0])
data.boxplot(column=["angka_harapan_hidup"], ax=axes[1, 1])
data.boxplot(column=["rerata_lama_sekolah"], ax=axes[1, 2])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Pemisahan Fitur dan Target

# %%
X = data.drop(columns='indeks_pembangunan_manusia')
X
# Out:
#       provinsi  angka_harapan_hidup  rerata_lama_sekolah  \
# 0            0               65.655                9.760
# 1            0               67.830                8.655
# 2            0               64.860                8.840
# 3            0               68.700               10.100
# 4            0               69.120                8.490
# ...        ...                  ...                  ...
# 7189        23               62.175                2.050
# 7190        23               64.590                1.365
# 7191        23               64.915                0.710
# 7192        23               64.160                3.360
# 7195        23               69.835               10.655
#
#       harapan_lama_sekolah  pengeluaran_per_kapita
# 0                    14.28                  7686.0
# 1                    14.35                  9374.0
# 2                    14.70                  8712.0
# 3                    14.27                  8566.0
# 4                    13.07                  9436.0
# ...                    ...                     ...
# 7189                  5.76                  3844.0
# 7190                  5.22                  4016.0
# 7191                  2.84                  4752.0
# 7192                  7.85                  4769.0
# 7195                 13.64                 13903.0
#
# [6274 rows x 5 columns]

# %%
y = data['indeks_pembangunan_manusia']
y
# Out:
# 0       68.06
# 1       70.14
# 2       68.44
# 3       71.05
# 4       69.32
#         ...
# 7189    39.37
# 7190    38.47
# 7191    33.44
# 7192    47.48
# 7195    76.69
# Name: indeks_pembangunan_manusia, Length: 6274, dtype: float64

# %% [markdown]
# ##### Normalisasi Data

# %%
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
df_X_normalized = pd.DataFrame(X_normalized, columns=X.columns)
joblib.dump(scaler, 'model scaling/fitur_mmscaler_model.pkl')
# Out:
# ['model scaling/fitur_mmscaler_model.pkl']

# %%
y_normalized = scaler.fit_transform(y.values.reshape(-1, 1))
df_y_normalized = pd.DataFrame(y_normalized, columns=['indeks_pembangunan_manusia'])
joblib.dump(scaler, 'model scaling/target_mmscaler_y.pkl')
# Out:
# ['model scaling/target_mmscaler_y.pkl']

# %%
df_X_normalized
# Out:
#       provinsi  angka_harapan_hidup  rerata_lama_sekolah  \
# 0      0.00000             0.513774             0.745590
# 1      0.00000             0.599370             0.658957
# 2      0.00000             0.482487             0.673461
# 3      0.00000             0.633609             0.772246
# 4      0.00000             0.650138             0.646021
# ...        ...                  ...                  ...
# 6269   0.69697             0.376820             0.141121
# 6270   0.69697             0.471861             0.087417
# 6271   0.69697             0.484652             0.036064
# 6272   0.69697             0.454939             0.243826
# 6273   0.69697             0.678276             0.815759
#
#       harapan_lama_sekolah  pengeluaran_per_kapita
# 0                 0.781568                0.205505
# 1                 0.785757                0.283075
# 2                 0.806703                0.252654
# 3                 0.780969                0.245945
# 4                 0.709156                0.285924
# ...                    ...                     ...
# 6269              0.271694                0.028951
# 6270              0.239378                0.036855
# 6271              0.096948                0.070677
# 6272              0.396768                0.071458
# 6273              0.743268                0.491200
#
# [6274 rows x 5 columns]

# %%
df_X_normalized.describe()
# Out:
#           provinsi  angka_harapan_hidup  rerata_lama_sekolah  \
# count  6274.000000          6274.000000          6274.000000
# mean      0.532708             0.646506             0.608850
# std       0.308264             0.142960             0.134414
# min       0.000000             0.000000             0.000000
# 25%       0.272727             0.559671             0.531164
# 50%       0.545455             0.657222             0.600353
# 75%       0.818182             0.742178             0.687181
# max       1.000000             1.000000             1.000000
#
#        harapan_lama_sekolah  pengeluaran_per_kapita
# count           6274.000000             6274.000000
# mean               0.673890                0.304775
# std                0.090525                0.123991
# min                0.000000                0.000000
# 25%                0.631358                0.221015
# 50%                0.676840                0.295368
# 75%                0.721724                0.371927
# max                1.000000                1.000000

# %%
df_y_normalized
# Out:
#       indeks_pembangunan_manusia
# 0                       0.705505
# 1                       0.735800
# 2                       0.711040
# 3                       0.749053
# 4                       0.723857
# ...                          ...
# 6269                    0.287649
# 6270                    0.274541
# 6271                    0.201282
# 6272                    0.405768
# 6273                    0.831197
#
# [6274 rows x 1 columns]

# %%
df_y_normalized.describe()
# Out:
#        indeks_pembangunan_manusia
# count                 6274.000000
# mean                     0.704888
# std                      0.102456
# min                      0.000000
# 25%                      0.651762
# 50%                      0.703903
# 75%                      0.760851
# max                      1.000000

# %% [markdown]
# ##### Menyimpan hasil normalisasi dan pemisahan data

# %%
df_X_normalized.to_csv('dataset/fitur.csv', index=False)
df_y_normalized.to_csv('dataset/target.csv', index=False)
